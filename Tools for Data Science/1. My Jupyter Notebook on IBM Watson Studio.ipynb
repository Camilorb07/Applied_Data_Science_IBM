# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Camilo Rivera Bedoya**
#
# Student

# %% [markdown]
# *I am interested in data science because I´m new in programming*

# %% [markdown]
# ### this code take 2 numbers and add them

# %%
x = int(input("first number: ")) #first number
y = int(input("second number: ")) #second number

z = x + y

print("sum: " + str(x) + " + " + str(y) + " = " + str(z))
# Out:
# first number: 1
# second number: 2
# sum: 1 + 2 = 3

# %% [markdown]
# * one
# * two
# * tree
#   * four
#   * five
#   * six
#
# [Google](https://www.google.com "Google's Homepage")
#
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3
